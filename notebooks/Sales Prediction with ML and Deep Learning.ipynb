# %% [markdown]
# ## Sales_Prediction_With_Machine_Learning and Deep_Learning

# %%
import os
print(os.getcwd())
# Out:
# c:\Customer-Behavior-Analysis-and-Sales-Prediction-with-Machine-Learning\notebooks

# %%
import sys
import pandas as pd
import numpy as np

# Get the current working directory of the notebook
current_dir = os.getcwd()

# Append the 'scripts' folder to sys.path
scripts_path = os.path.join(current_dir, 'scripts')
if scripts_path not in sys.path:
    sys.path.append(scripts_path)

# %%
import sys
import os

# Full path to the 'scripts' folder
scripts_path = r'c:\Customer-Behavior-Analysis-and-Sales-Prediction-with-Machine-Learning\scripts'

# Check if the path exists
if os.path.isdir(scripts_path):
    sys.path.append(scripts_path)
    print("Scripts folder found and added to sys.path!")
else:
    print("Scripts folder NOT found. Check the path.")

# Now try importing the module
try:
    from scripts.data_loader import load_data
    print("Module imported successfully!")
except ModuleNotFoundError as e:
    print(f"Error importing module: {e}")
# Out:
# Scripts folder found and added to sys.path!
# c:\Customer-Behavior-Analysis-and-Sales-Prediction-with-Machine-Learning\scripts\data_loader.py:10: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_path)
# 2025-01-13 13:37:41,780 - INFO - Loaded data from E:/10Academy/Data04/train.csv with shape (1017209, 9)
# 2025-01-13 13:37:41,898 - INFO - Loaded data from E:/10Academy/Data04/store.csv with shape (1115, 10)
# 2025-01-13 13:37:42,477 - INFO - Loaded data from E:/10Academy/Data04/test.csv with shape (41088, 8)
# Module imported successfully!

# %%
# Get the current working directory of the notebook
current_dir = os.getcwd()

# Append the 'scripts' folder to sys.path
scripts_path = os.path.join(current_dir, 'scripts')
if scripts_path not in sys.path:
    sys.path.append(scripts_path)

# %%
# Define file paths for your data
file_path = 'E:/10Academy/Data04'

# %%
# Define file paths for your data
file_path = 'E:/10Academy/Data04'

# Load datasets
try:
    train = load_data(file_path + '/train.csv')
    store = load_data(file_path + '/store.csv')
    test  = load_data(file_path + '/test.csv')
except Exception as e:
    print(f"Data loading failed: {e}")
# Out:
# c:\Customer-Behavior-Analysis-and-Sales-Prediction-with-Machine-Learning\scripts\data_loader.py:10: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_path)
# 2025-01-13 13:43:43,834 - INFO - Loaded data from E:/10Academy/Data04/train.csv with shape (1017209, 9)
# 2025-01-13 13:43:43,850 - INFO - Loaded data from E:/10Academy/Data04/store.csv with shape (1115, 10)
# 2025-01-13 13:43:44,010 - INFO - Loaded data from E:/10Academy/Data04/test.csv with shape (41088, 8)

# %%
# Import modules
from scripts.data_loader import load_data, preprocess_data
from scripts.model_training import train_random_forest, train_lstm, create_sliding_window  # Import create_sliding_window
from scripts.plot import (
    plot_sales_over_time, plot_differenced_sales, plot_training_validation_loss, plot_predictions, plot_future_predictions
)

# %%
# Load and preprocess data
train_path = r'E:\10Academy\Data04\train.csv'
test_path = r'E:\10Academy\Data04\test.csv'
store_path = r'E:\10Academy\Data04\store.csv'

# Load the data
train_df, test_df, store_df = load_data(train_path, test_path, store_path)

# Preprocess the data
train_df, test_df, scaler = preprocess_data(train_df, test_df, store_df)

# %%
# Train RandomForestRegressor: Train a Random Forest model to predict sales based on the training data
rf_pipeline = train_random_forest(train_df)

# Train LSTM: Train an LSTM model on the training data and return the model, scaler, window size, validation data, and history
lstm_model, lstm_scaler, window_size, X_val, y_val, history = train_lstm(train_df)

# Make predictions: Select data for a specific store and sort it by date to use for visualization and prediction
store_id = 1
store_data = train_df[train_df['Store'] == store_id][['Date', 'Sales']]
store_data = store_data.sort_values('Date')

# Plot 1: Sales Over Time: Plot the sales data for the store over time
plot_sales_over_time(store_data)

# Plot 2: Differenced Sales Over Time: Plot the differenced sales data to visualize stationarity
store_data['SalesDiff'] = store_data['Sales'].diff().dropna()
plot_differenced_sales(store_data)

# Plot 3: Training and Validation Loss: Plot the loss curves for the training and validation phases of the LSTM model
plot_training_validation_loss(history)

# Plot 4: Predictions vs. Actual Values: Compare the LSTM model's predictions to actual values in the validation data
y_pred = lstm_model.predict(X_val)
y_pred_inv = lstm_scaler.inverse_transform(y_pred)
y_val_inv = lstm_scaler.inverse_transform(y_val)
plot_predictions(y_val_inv, y_pred_inv)

# Plot 5: Future Predictions: Predict the next 30 days of sales using the trained LSTM model with a sliding window approach
future_dates = pd.date_range(start=store_data['Date'].max(), periods=30, freq='D')  # Predict for the next 30 days

# Ensure there are enough data points for the sliding window: Check if the dataset has enough rows for prediction
if len(store_data) >= window_size + 1:  # Need at least window_size + 1 rows
    # Use the last window_size + 1 rows for future_scaled_sales: Prepare the most recent data for future prediction
    future_scaled_sales = lstm_scaler.transform(store_data[['Sales']].tail(window_size + 1))
    
    # Create sliding window data for future predictions: Generate the data format for LSTM input for future predictions
    future_X, _ = create_sliding_window(future_scaled_sales, window_size)
    
    if len(future_X) > 0:  # Check if future_X is not empty
        # Reshape future_X for LSTM input: Ensure correct shape for LSTM model input
        future_X = future_X.reshape(future_X.shape[0], future_X.shape[1], 1)
        
        # Make predictions for the next 30 days: Generate the next 30 days of sales predictions using the LSTM model
        future_predictions = []
        current_sequence = future_X[-1]  # Start with the last sequence
        
        for _ in range(len(future_dates)):
            # Predict the next value: Make a prediction for the next day's sales
            next_prediction = lstm_model.predict(current_sequence.reshape(1, window_size, 1))
            future_predictions.append(next_prediction[0, 0])
            
            # Update the sequence with the new prediction: Update the sequence for the next prediction
            current_sequence = np.roll(current_sequence, -1)
            current_sequence[-1] = next_prediction
        
        # Inverse transform the predictions: Rescale the predicted sales back to the original scale
        future_predictions = np.array(future_predictions).reshape(-1, 1)
        future_predictions_inv = lstm_scaler.inverse_transform(future_predictions)
        
        # Plot future predictions: Plot the predicted sales for the next 30 days
        plot_future_predictions(future_dates, future_predictions_inv)
    else:
        print("Not enough data points to create future predictions.")
else:
    print(f"Not enough data points for sliding window. Required: {window_size + 1}, Available: {len(store_data)}")
# Out:
# Trial 5 Complete [00h 00m 40s]
# val_loss: 0.04613167295853297
#
# Best val_loss So Far: 0.04613167295853297
# Total elapsed time: 00h 04m 44s
# 2025-01-10 16:46:42,560 - INFO - Best Hyperparameters: <keras_tuner.src.engine.hyperparameters.hyperparameters.HyperParameters object at 0x0000027A212DEC90>
# 2025-01-10 16:46:42,561 - INFO - Training the final LSTM model.
# Epoch 1/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - loss: 0.1972 - val_loss: 0.1326
# Epoch 2/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1849 - val_loss: 0.1214
# Epoch 3/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1471 - val_loss: 0.0852
# Epoch 4/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0776 - val_loss: 0.1028
# Epoch 5/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0812 - val_loss: 0.0755
# Epoch 6/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0798 - val_loss: 0.0856
# Epoch 7/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0861 - val_loss: 0.0811
# ...

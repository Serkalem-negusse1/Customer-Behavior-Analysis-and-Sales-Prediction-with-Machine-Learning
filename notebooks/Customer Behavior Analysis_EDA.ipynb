# %% [markdown]
# ## Exploratory_Data_Analysis_Sales_and_Promotions

# %%
import os
print(os.getcwd())
# Out:
# c:\Customer-Behavior-Analysis-and-Sales-Prediction-with-Machine-Learning\notebooks

# %%
import sys
import pandas as pd

# Get the current working directory of the notebook
current_dir = os.getcwd()

# Append the 'scripts' folder to sys.path
scripts_path = os.path.join(current_dir, 'scripts')
if scripts_path not in sys.path:
    sys.path.append(scripts_path)

# %%
import os

# Change the current working directory to the project root
os.chdir(r'c:\Customer-Behavior-Analysis-and-Sales-Prediction-with-Machine-Learning')
print("Current Directory:", os.getcwd())

# Now check if the 'scripts' folder exists
print("Scripts Path Exists:", os.path.isdir('scripts'))
# Out:
# Current Directory: c:\Customer-Behavior-Analysis-and-Sales-Prediction-with-Machine-Learning
# Scripts Path Exists: True

# %%
import sys
import os

# Full path to the 'scripts' folder
scripts_path = r'c:\Customer-Behavior-Analysis-and-Sales-Prediction-with-Machine-Learning\scripts'

# Check if the path exists
if os.path.isdir(scripts_path):
    sys.path.append(scripts_path)
    print("Scripts folder found and added to sys.path!")
else:
    print("Scripts folder NOT found. Check the path.")

# Now try importing the module
try:
    from data_loader import load_data
    print("Module imported successfully!")
except ModuleNotFoundError as e:
    print(f"Error importing module: {e}")
# Out:
# Scripts folder found and added to sys.path!
# C:\Customer-Behavior-Analysis-and-Sales-Prediction-with-Machine-Learning\scripts\data_loader.py:10: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_path)
# 2025-01-13 11:53:29,993 - INFO - Loaded data from E:/10Academy/Data04/train.csv with shape (1017209, 9)
# 2025-01-13 11:53:30,013 - INFO - Loaded data from E:/10Academy/Data04/store.csv with shape (1115, 10)
# 2025-01-13 11:53:30,052 - INFO - Loaded data from E:/10Academy/Data04/test.csv with shape (41088, 8)
# Module imported successfully!

# %%
import os
print("Current Directory:", os.getcwd())
print("Scripts Path Exists:", os.path.isdir('scripts'))
print("Data Loader Exists:", os.path.isfile('scripts/data_loader.py'))
print("processed Data Exists:", os.path.isfile('scripts/data_preprocessing.py'))
# Out:
# Current Directory: c:\Customer-Behavior-Analysis-and-Sales-Prediction-with-Machine-Learning
# Scripts Path Exists: True
# Data Loader Exists: True
# processed Data Exists: True

# %%
from data_preprocessing import (
    load_data, detect_missing_values, detect_outliers, outlier_detection, preprocess_dates,
    handle_missing_values, visualize_missing_data, visualize_outliers
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 from data_preprocessing import (
#       2     load_data, detect_missing_values, detect_outliers, outlier_detection, preprocess_dates,
#       3     handle_missing_values, visualize_missing_data, visualize_outliers
#       4 )
#
# ImportError: cannot import name 'outlier_detection' from 'data_preprocessing' (C:\Customer-Behavior-Analysis-and-Sales-Prediction-with-Machine-Learning\scripts\data_preprocessing.py)

# %%
from data_preprocessing import (
    load_data,detect_missing_values,detect_outliers,outlier_detection,preprocess_data,
    visualize_missing_values,visualize_outliers,compare_outliers)

from EDA import (
    plot_promotion_distribution,
    analyze_sales_holidays,
    plot_monthly_sales_trend,
    analyze_sales_on_key_dates,
    plot_sales_vs_customers,
    plot_promo_effectiveness,
    plot_customer_trends_by_day,
    plot_weekend_vs_weekday_sales,
    plot_sales_vs_competitor_distance,
    plot_city_center_sales,
    plot_sales_trend_before_after_competitor_opening,
    compare_promo_effect,
    compare_assortment_sales
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 from data_preprocessing import (
#       2     load_data,detect_missing_values,detect_outliers,outlier_detection,preprocess_data,
#       3     visualize_missing_values,visualize_outliers,compare_outliers)
#       5 from EDA import (
#       6     plot_promotion_distribution,
#       7     analyze_sales_holidays,
#    (...)
#      18     compare_assortment_sales
#      19 )
#
# ImportError: cannot import name 'outlier_detection' from 'data_preprocessing' (C:\Customer-Behavior-Analysis-and-Sales-Prediction-with-Machine-Learning\scripts\data_preprocessing.py)

# %%
# Import the custom script
from scripts.data_loader import load_data


# Define file paths for your data
file_path = 'E:/10Academy/Data04'

# Load datasets
try:
    train = load_data(file_path + '/train.csv')
    store = load_data(file_path + '/store.csv')
    test  = load_data(file_path + '/test.csv')
except Exception as e:
    print(f"Data loading failed: {e}")
# Out:
# c:\Customer-Behavior-Analysis-and-Sales-Prediction-with-Machine-Learning\scripts\data_loader.py:10: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_path)
# 2025-01-13 12:37:43,320 - INFO - Loaded data from E:/10Academy/Data04/train.csv with shape (1017209, 9)
# 2025-01-13 12:37:43,351 - INFO - Loaded data from E:/10Academy/Data04/store.csv with shape (1115, 10)
# 2025-01-13 12:37:43,436 - INFO - Loaded data from E:/10Academy/Data04/test.csv with shape (41088, 8)

# %%
import sys
sys.path.append('./scripts')  # Add the 'scripts' folder to the path

# %%
from scripts.data_loader import load_data

file_path = 'E:/10Academy/Data04'

# %%
print("\nStore Data:")
store.head()
# Out:
# Store Data:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# ...

# %%
# Display the first few rows of the train dataset
print("\nTrain Data:")
train.head()
# Out:
# Train Data:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
print("\nTest Data:")
test.head()
# Out:
# Test Data:
#    Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  SchoolHoliday
# 0   1      1          4  2015-09-17   1.0      1            0              0
# 1   2      3          4  2015-09-17   1.0      1            0              0
# 2   3      7          4  2015-09-17   1.0      1            0              0
# 3   4      8          4  2015-09-17   1.0      1            0              0
# 4   5      9          4  2015-09-17   1.0      1            0              0

# %%
import sys
sys.path.append(r'C:\Customer-Behavior-Analysis-and-Sales-Prediction-with-Machine-Learning\scripts')

# %%
import numpy as np
# Handle and visualize missing values and outliers for both datasets
print("Missing Values:")
missing_summary = detect_missing_values(train)
print(missing_summary)

# Detect Outliers
print("\nOutliers:")
outliers_summary = detect_outliers(train, train.select_dtypes(include=[np.number]).columns.tolist())
print(outliers_summary)
# Out:
# 2025-01-13 12:47:21,813 - INFO - Detecting outliers.
# 2025-01-13 12:47:21,843 - INFO - Outliers detected in Store: 0
# 2025-01-13 12:47:21,868 - INFO - Outliers detected in DayOfWeek: 0
# Missing Values:
#                Missing Values  Percentage
# Store                       0         0.0
# DayOfWeek                   0         0.0
# Date                        0         0.0
# Sales                       0         0.0
# Customers                   0         0.0
# Open                        0         0.0
# Promo                       0         0.0
# StateHoliday                0         0.0
# SchoolHoliday               0         0.0
#
# Outliers:
# 2025-01-13 12:47:21,915 - INFO - Outliers detected in Sales: 26694
# 2025-01-13 12:47:21,972 - INFO - Outliers detected in Customers: 38095
# 2025-01-13 12:47:22,010 - INFO - Outliers detected in Open: 172817
# 2025-01-13 12:47:22,039 - INFO - Outliers detected in Promo: 0
# ...

# %%
train = preprocess_data(train)
    
print("\nAfter Preprocessing:")
print(train.head())
print(train.isnull().sum())
# Out:
# 2025-01-03 20:23:31,479 - INFO - Preprocessing data by handling missing values and outliers.
# 2025-01-03 20:23:31,480 - INFO - Handling missing values.
# 2025-01-03 20:23:31,481 - INFO - Handling outliers.
# 2025-01-03 20:23:31,481 - INFO - Preprocessing completed.
# After Preprocessing:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
# Store            0
# DayOfWeek        0
# Date             0
# Sales            0
# Customers        0
# ...

# %%
store = preprocess_data(store)
    
print("\nAfter Preprocessing:")
print(store.head())
print(store.isnull().sum())
# Out:
# 2025-01-03 20:23:31,610 - INFO - Preprocessing data by handling missing values and outliers.
# 2025-01-03 20:23:31,611 - INFO - Handling missing values.
# 2025-01-03 20:23:31,614 - INFO - Filled missing values in CompetitionDistance with median.
# 2025-01-03 20:23:31,616 - INFO - Filled missing values in CompetitionOpenSinceMonth with mode.
# 2025-01-03 20:23:31,617 - INFO - Filled missing values in CompetitionOpenSinceYear with mode.
# 2025-01-03 20:23:31,619 - INFO - Filled missing values in Promo2SinceWeek with mode.
# 2025-01-03 20:23:31,621 - INFO - Filled missing values in Promo2SinceYear with mode.
# 2025-01-03 20:23:31,623 - INFO - Filled missing values in PromoInterval with 'None'.
# 2025-01-03 20:23:31,624 - INFO - Handling outliers.
# 2025-01-03 20:23:31,628 - INFO - Capped outliers in CompetitionDistance.
# 2025-01-03 20:23:31,632 - INFO - Capped outliers in CompetitionOpenSinceYear.
# 2025-01-03 20:23:31,633 - INFO - Preprocessing completed.
# After Preprocessing:
# ...

# %%
plot_promotion_distribution(train, test)
# Out:
# 2025-01-03 20:23:31,653 - INFO - Plotting promotion distribution for training and test datasets.
# 2025-01-03 20:23:33,362 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-01-03 20:23:34,702 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-01-03 20:23:35,428 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-01-03 20:23:35,487 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# ...

# %%
analyze_sales_holidays(train)
# Out:
# 2025-01-03 20:23:35,745 - INFO - Analyzing sales during holidays.
# 2025-01-03 20:23:38,999 - INFO - Sales analysis during holidays completed.

# %%
plot_monthly_sales_trend(train)
# Out:
# 2025-01-03 20:23:39,012 - INFO - Plotting monthly sales trend.
# 2025-01-03 20:23:39,713 - INFO - Monthly sales trend plotted.

# %%
analyze_sales_on_key_dates(train)
# Out:
# 2025-01-03 20:23:39,728 - INFO - Analyzing sales on key holiday dates.
# 2025-01-03 20:23:47,610 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-01-03 20:23:47,613 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-01-03 20:23:47,813 - INFO - Sales analysis on key holiday dates completed.

# %%
compare_promo_effect(train)
compare_assortment_sales(train, store)
# Out:
# 2025-01-03 20:23:47,908 - INFO - Promo Effect:
#              Sales   Customers
# Promo
# 0      4406.050805  517.823542
# 1      7991.152046  820.098815
# 2025-01-03 20:23:48,071 - INFO - Promo Effect with SalesPerCustomer:
#              Sales   Customers  SalesPerCustomer
# Promo
# 0      4406.050805  517.823542          8.508788
# 1      7991.152046  820.098815          9.744133

# %%
plot_sales_vs_customers(train)
# Out:
# 2025-01-03 20:23:49,049 - INFO - Correlation between Sales and Customers: 0.8947107733016958

# %%
plot_promo_effectiveness(train)
# Out:
# 2025-01-03 20:23:55,970 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-01-03 20:23:55,978 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-01-03 20:23:56,342 - INFO - Promo effectiveness plot created successfully.

# %%
plot_customer_trends_by_day(train)

# %%
plot_weekend_vs_weekday_sales(train)
# Out:
# 2025-01-03 20:23:57,429 - INFO - Weekend vs Weekday sales plot created successfully.

# %%
train_store = pd.merge(train, store, on='Store')

plot_sales_vs_competitor_distance(train_store)
# Out:
# 2025-01-03 20:23:58,224 - INFO - Correlation between Competitor Distance and Sales:
#                      CompetitionDistance     Sales
# CompetitionDistance             1.000000 -0.025302
# Sales                          -0.025302  1.000000

# %%
plot_city_center_sales(train_store)

# %%
plot_sales_trend_before_after_competitor_opening(train_store)
# Out:
# 2025-01-03 20:24:19,492 - INFO - Starting to process 'plot_sales_trend_before_after_competitor_opening'...
# 2025-01-03 20:24:19,579 - INFO - Date column successfully converted to datetime.
# 2025-01-03 20:24:20,715 - INFO - YearMonth column created for grouping.
# 2025-01-03 20:24:40,189 - INFO - Competitor opening dates processed.
# 2025-01-03 20:24:40,638 - INFO - Filtered stores where competitor opened: 1017209 rows.
# 2025-01-03 20:24:40,852 - INFO - Calculated average sales before and after competitor opening.
# 2025-01-03 20:24:40,861 - INFO - Earliest competitor opening date is: 2000-01
# 2025-01-03 20:24:40,885 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# ...
